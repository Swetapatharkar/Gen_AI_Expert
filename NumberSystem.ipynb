# %%
bin(12)
# Out:
# '0b1100'

# %%
int(0b1100)
# Out:
# 12

# %%
oct(24)
# Out:
# '0o30'

# %%
int(0o30)
# Out:
# 24

# %%
hex(25)
# Out:
# '0x19'

# %%
int(0x19)
# Out:
# 25

# %%
~23
# Out:
# -24

# %%
~55
# Out:
# -56

# %%
12 &13
# Out:
# 12

# %%
12 | 13
# Out:
# 13

# %%
1 & 0
# Out:
# 0

# %%
1 | 0
# Out:
# 1

# %%
35 & 40
# Out:
# 32

# %%
35 | 40
# Out:
# 43

# %%
12 ^ 13
# Out:
# 1

# %%
25 ^ 56
# Out:
# 33

# %%
10<<1
# Out:
# 20

# %%
10>>1
# Out:
# 5
