# %%
list1=[]
print(type(list1))
# Out:
# <class 'list'>

# %%
list2=[10,20,30]
list3=[10.77,30.98,66.87]
list4=['one','two','three']
list5=['samplestring',23,55.7,[50,100],[150,90]]
list6=[100,'Radha',44.34]
list7=['Radha',25,[50,100],[150,90],{'John','David'}]
len(list7)
# Out:
# 5

# %%
list2
# Out:
# [10, 20, 30]

# %%
list2[0]
# Out:
# 10

# %%
list4
# Out:
# ['one', 'two', 'three']

# %%
list4[-1]
# Out:
# 'three'

# %%
print(list5)
list5[-1]
# Out:
# ['samplestring', 23, 55.7, [50, 100], [150, 90]]
# [150, 90]

# %%
mylist=['one','two','three','four','five','six','seven','eight']

# %%
mylist[0:3]
# Out:
# ['one', 'two', 'three']

# %%
mylist[2:5]
mylist[:3]
# Out:
# ['one', 'two', 'three']

# %%
mylist[:-3]
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %%
mylist[-2:]
# Out:
# ['seven', 'eight']

# %%
mylist[-1]
# Out:
# 'eight'

# %%
mylist[:]
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
mylist.append('nine')
mylist
# Out:
# ['one',
#  'two',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'eight',
#  'nine',
#  'nine']

# %%
mylist.insert(0,'HELLO')
mylist
# Out:
# ['HELLO',
#  'one',
#  'two',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'eight',
#  'nine',
#  'nine']

# %%
mylist.remove('HELLO')
print(mylist)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 mylist.remove('HELLO')
#       2 print(mylist)
#
# ValueError: list.remove(x): x not in list

# %%
mylist.pop()
# Out:
# 'nine'

# %%
mylist.pop(8)
# Out:
# 'nine'

# %%
del mylist[7]
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven']

# %%
mylist[0]=1
mylist[1]=2
mylist[2]=3
mylist
# Out:
# [1, 2, 3, 'four', 'five', 'six', 'seven']

# %%
mylist.clear()
mylist
# Out:
# []

# %%
del mylist
mylist
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 del mylist
# ----> 2 mylist
#
# NameError: name 'mylist' is not defined

# %%
mylist= ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine' ]

# %%
mylist1=mylist

# %%
print(id(mylist))
print(id(mylist1))
# Out:
# 3046708931840
# 3046708931840

# %%
mylist2=mylist.copy()

# %%
id(mylist2)
# Out:
# 3046709309376

# %%
mylist[0]=1
mylist
# Out:
# [1, 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist1
# Out:
# [1, 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist2
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
list1=['one', 'two', 'three', 'four']
list2=['five', 'six', 'seven', 'eight']

# %%
list3=list1+list2
list3
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list1.extend(list2)
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
'one' in list1
# Out:
# True

# %%
'ten' in list1
# Out:
# False

# %%
if 'three'in list1:
    print('three is present in list1')
else:
    print('three is not present in list1')
# Out:
# three is present in list1

# %%
if 'eleven' in list1:
    print("Eleven is present in List1")
else:
    print("Eleven is not present in List1")
# Out:
# Eleven is not present in List1

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list1.reverse()
list1
# Out:
# ['eight', 'seven', 'six', 'five', 'four', 'three', 'two', 'one']

# %%
list1=list1[::-1]
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list3=[23,33,55,1,5,77,88,55,34,5]
list3.sort()
list3
# Out:
# [1, 5, 5, 23, 33, 34, 55, 55, 77, 88]

# %%
list3.sort(reverse=True)
list3
# Out:
# [88, 77, 55, 55, 34, 33, 23, 5, 5, 1]

# %%
list4=[23,44,34,78,6,98,12]
sorted(list4)
# Out:
# [6, 12, 23, 34, 44, 78, 98]

# %%
list4
# Out:
# [23, 44, 34, 78, 6, 98, 12]

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
for i in list1:
    print(i)
# Out:
# one
# two
# three
# four
# five
# six
# seven
# eight

# %%
for i in enumerate(list1):
    print(i)
# Out:
# (0, 'one')
# (1, 'two')
# (2, 'three')
# (3, 'four')
# (4, 'five')
# (5, 'six')
# (6, 'seven')
# (7, 'eight')

# %%
list10 =['one', 'two', 'three', 'four', 'one', 'one', 'two', 'three']

# %%
list10.count('one')
# Out:
# 3

# %%
list10.count('two')
# Out:
# 2

# %%
list10.count('three')
# Out:
# 2

# %%
L1=[1,2,3,4,0]

# %%
all(L1)
# Out:
# False

# %%
any(L1)
# Out:
# True

# %%
L2 = [1,2,3,4,True,False]

# %%
all(L2)
# Out:
# False

# %%
any(L2)
# Out:
# True

# %%
L3 = [1,2,3,True]

# %%
all(L3)
# Out:
# True

# %%
any(L3)
# Out:
# True
