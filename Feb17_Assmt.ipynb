# %%
import sys
import keyword
sys.version
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
i=56
i
# Out:
# 56

# %%
id(i)
# Out:
# 140713924668040

# %%
t=10
id(t)
# Out:
# 140713924666568

# %%
False
# Out:
# False

# %%
True
# Out:
# True

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
print(3+3)
# Out:
# 6

# %%
print(4+9)
# Out:
# 13

# %%
print(12*7)
# Out:
# 84

# %%
print(100/5)
# Out:
# 20.0

# %%
print(23/4)
# Out:
# 5.75

# %%
print(3/88)
# Out:
# 0.03409090909090909

# %%
print(3**6)
# Out:
# 729

# %%
print(2**2)
# Out:
# 4

# %%
print(23%3)
# Out:
# 2

# %%
print(3%2)
# Out:
# 1

# %%
print(34%6)
# Out:
# 4

# %%
print(3//2)
# Out:
# 1

# %%
print(34//6)
# Out:
# 5

# %% [markdown]
# Checking the datatype

# %%
print(type(10))
# Out:
# <class 'int'>

# %%
print(type(Radha))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 print(type(Radha))
#
# NameError: name 'Radha' is not defined

# %%
print(type('Radha'))
# Out:
# <class 'str'>

# %%
print(type(2.14))
# Out:
# <class 'float'>

# %%
print(type(3+6i))
# Out:
#   Cell In[39], line 1
#     print(type(3+6i))
#                  ^
# SyntaxError: invalid decimal literal

# %%
print(type(1+3j))
# Out:
# <class 'complex'>

# %%
In Python imaginary number is only j not i

# %%
print(type([2,4,6,8,9,0]))
# Out:
# <class 'list'>

# %%
print(type({'Date','Days'}))
# Out:
# <class 'set'>

# %%
print(type({'Date':'Days'}))
# Out:
# <class 'dict'>

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\ADMIN
