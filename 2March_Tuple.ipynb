# %%
tup1=(1,2,3,4,5)
tup1
tup2=('Radha','Narayan','Krishna')
tup2
tup3=(12.,33,55)
tup3
tup4=('Radha',2+4j,(12,33),(99,87))
tup4
tup5=({'Radha','Krishna'},[100,200],88,'Govind',(5+8j))
tup5
len(tup5)
# Out:
# 5

# %%
tup5[0]
# Out:
# {'Krishna', 'Radha'}

# %%
tup5[1]
# Out:
# [100, 200]

# %%
tup5[0][1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 tup5[0][1]
#
# TypeError: 'set' object is not subscriptable

# %%
tup2[0][0]
# Out:
# 'R'

# %%
tup5[-1]
# Out:
# (5+8j)

# %%
mytuple=('one','two','three','four','five','six','seven','eight')
mytuple[0:3]
# Out:
# ('one', 'two', 'three')

# %%
mytuple[2:5]
# Out:
# ('three', 'four', 'five')

# %%
mytuple[:3]
# Out:
# ('one', 'two', 'three')

# %%
mytuple[-3:]
# Out:
# ('six', 'seven', 'eight')

# %%
mytuple[0]
# Out:
# 'one'

# %%
del mytuple[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 del mytuple[0]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
mytuple[1]='eleven'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 mytuple[1]='eleven'
#
# TypeError: 'tuple' object does not support item assignment

# %%
del mytuple

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
for i in mytuple:
    print(i)
# Out:
# one
# two
# three
# four
# five
# six
# seven
# eight

# %%
for i in enumerate(mytuple):
    print(i)
# Out:
# (0, 'one')
# (1, 'two')
# (2, 'three')
# (3, 'four')
# (4, 'five')
# (5, 'six')
# (6, 'seven')
# (7, 'eight')

# %%
'one' in mytuple
# Out:
# True

# %%
'ten' in mytuple
# Out:
# False

# %%
mytuple.index('four')
# Out:
# 3

# %%
mytuple2=(1,3,6,8,3,5,7,0)
sorted(mytuple2)
# Out:
# [0, 1, 3, 3, 5, 6, 7, 8]

# %%
sorted(mytuple2,reverse=True)
# Out:
# [8, 7, 6, 5, 3, 3, 1, 0]
