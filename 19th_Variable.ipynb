# %%
age=25
print(age)
# Out:
# 25

# %%
name="Radha"
print(name)
# Out:
# Radha

# %%
price=19.99
print(price)
# Out:
# 19.99

# %%
is_active=True
print(is_active)
# Out:
# True

# %%
a=5
b=2
result=a+b
print(result)
# Out:
# 7

# %%
first_name=input("Enter your first Name")
last_name=input("Enter ypur last name")
full_name=first_name +" "+last_name
print(full_name)
# Out:
# Enter your first Name Sweta
# Enter ypur last name Patharkar
# Sweta Patharkar

# %%
x=10
print(x)
x=20
print(x)
# Out:
# 10
# 20
