# %%
x1 = input('user_name') #whenevery you works in input function it always give you string 
y1 = input('password') # it wont understand as arithmetic operator
z1 = x1 + y1
print(z1)
# Out:
# user_name test
# password 1111
# test1111

# %%
st=input('Enter a string')[0:3]
print(st)
# Out:
# Enter a string qbcdefghijklmno
# qbc

# %%
st=int(input('Enter a string'))
print(str)
# Out:
# Enter a string 12+12=24
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 st=int(input('Enter a string'))
#       2 print(str)
#
# ValueError: invalid literal for int() with base 10: '12+12=24'

# %%
result = eval(input('enter an expr'))
print(result)
# Out:
# enter an expr 12+12-12
# 12

# %%
import math
math.sqrt(81)
# Out:
# 9.0

# %%
round(math.sqrt(100))
# Out:
# 10

# %%
print(math.floor(3.14))
print(math.ceil(3.14))
# Out:
# 3
# 4

# %%
math.pow(3,3) #output is 27
round(math.pow(4,2))# Syntax: math.pow(base, exponent)
# Out:
# 16

# %%
from math import sqrt,ceil,pow,floor
print(pow(2,2))
print(sqrt(81))
print(ceil(3.14))
print(floor(3.14))
# Out:
# 4.0
# 9.0
# 4
# 3

# %%
from math import *
print(pow(2,4))
print(sqrt(100))
print(ceil(9.14))
print(floor(3.99))
# Out:
# 16.0
# 10.0
# 10
# 3
