# %%
student = {"name": "John", "age": 20}

for key, value in student.items():
    print(key, value)
# Out:
# name John
# age 20

# %%
#for i in range(5):
   # print(i)
for i in range(3,6):
 print(i)
# Out:
# 3
# 4
# 5

# %%
for i in range(1, -4, -2):
    print(i)
# Out:
# 1
# -1
# -3

# %%
for letter in "NARAYAN":
 print(letter)
# Out:
# N
# A
# R
# A
# Y
# A
# N

# %%
student = {"Name":"Radha","Age":12,"Occupation":"Job"}
for key,value in student.items():
  print(key,value)
# Out:
# Name Radha
# Age 12
# Occupation Jo  b

# %%
for i in range(5):
    if i == 3:
        break
    print(i)
# Out:
# 0
# 1
# 2

# %%
startups = ["NeuralNet", "DeepMind", "OpenAI"]

for name in startups:
    print(f"I want to work at {name}")
# Out:
# I want to work at NeuralNet
# I want to work at DeepMind
# I want to work at OpenAI

# %%
battery = 30

while battery > 0:
    print(f"AI is processing... Battery at {battery}%")
    battery -= 10  # This is crucial! Without it, you get an infinite loop.

print("System shutdown.")
# Out:
# AI is processing... Battery at 30%
# AI is processing... Battery at 20%
# AI is processing... Battery at 10%
# System shutdown.

# %%
agents_list = [
    {"name": "Alpha", "active": True},
    {"name": "Beta", "active": False},
    {"name": "Gamma", "active": True}
]

for agent in agents_list:
    if agent["active"] == True:
        print(f"Agent {agent['name']} is ready for duty!")
# Out:
# Agent Alpha is ready for duty!
# Agent Gamma is ready for duty!
